# %% [markdown]
# # Project 07 - Semaphores and Deadlocks

# %% [markdown]
# ## Abstract
#
# This week, we focus on the concept of a sempahore as a way to synchronize various processes in an efficent way all the while avoiding problems that come from multithreading (such as race conditions). We will implement a simple semaphore and test it against a producer/consumer program created by professor Al Madi. We will then use our semaphores to solve the dining philosopher's problem.

# %% [markdown]
# ## Results and Discussion
#
# We build our semaphore by implementing an acquire and a release method. The acquire method sleeps a thread if the counter falls below zero and the release method wakes up a thread once the condition variable has been released. We test our function below: We have a place and a remove method implemented by professor Al Madi. The producer and the consumer methods below then place and remove items from a buffer. We expect to see no errors, the buffer size should never exceed ten, and all items should be removed from the buffer at the end of each run.

# %%
import threading
import time
import random
import semaphore

class Buffer:
     
    def __init__(self, size):
        self.size = size
        self.queue = []
        self.lock = threading.Lock()
        self.full = semaphore.Semaphore(0)
        self.empty = semaphore.Semaphore(self.size)
        
    def place(self, item):
        self.empty.acquire()
        
        self.lock.acquire()
        self.queue.append(item)
        self.lock.release()
        
        self.full.release()

        
    def remove(self):
        self.full.acquire()
        
        self.lock.acquire()
        item = self.queue.pop(0)
        self.lock.release()
        
        self.empty.release()
        
        return item

# %%
my_buffer = Buffer(10)

# %%
def producer():
    for item in range(100):
        print("adding item:", item, "\tbuffer length:", len(my_buffer.queue))
        my_buffer.place(item)

# %%
def consumer():
    for index in range(100):
        item = my_buffer.remove()
        print("removing item:", item, "\tbuffer length:", len(my_buffer.queue))

# %%
t1 = threading.Thread(target=producer)
t2 = threading.Thread(target=consumer)

t1.start()
t2.start()

t1.join()
t2.join()
# Out:
# adding item: 0 	buffer length: 0
# adding item: 1 	buffer length: 1
# adding item: 2 	buffer length:removing item: 0 	buffer length: 1
# removing item: 1 	buffer length: 0
#  2
# adding item: 3 	buffer length: removing item: 2 	buffer length: 0
# 1
# adding item: removing item: 3 	buffer length: 0
# 4 	buffer length: 1
# adding item: 5 	buffer length: 1
# removing item: 4 	buffer length: 0
# adding item: 6 	buffer length: 1removing item: 5 	buffer length: 0
#
# adding item: 7 	buffer length: 1
# adding item: 8 removing item: 6 	buffer length: 1
# removing item: 7 	buffer length: 0
# 	buffer length: 2
# adding item:removing item: 8 	buffer length: 0
#  9 	buffer length: 1
# adding item: 10 	buffer length: 1
# adding item: 11 	buffer length: removing item: 9 	buffer length: 1
# removing item: 10 	buffer length: 0
# 2
# adding item: 12 	buffer length: 1
# adding item: 13 removing item: 11 	buffer length: 2
# adding item: 14 	buffer length: 2
# adding item: 15 	buffer length: 3
# adding item: 16 	buffer length: 4
# adding item: 17 	buffer length: 5
# adding item: 18 	buffer length: 6
# adding item: 19 	buffer length: 7
# adding item: 20 	buffer length: 8
# adding item: 21 	buffer length: 9
# adding item: 22 	buffer length: 10
# 	buffer length: 1
# removing item: 12 	buffer length: 9
# removing item: 13adding item: 23 	buffer length: 8
# removing item: 14 	buffer length: 8
# removing item: 15 	buffer length: 9 	buffer length: 7
# removing item: 16 	buffer length: 6
# removing item: 17 	buffer length:
# 5
# removing item:adding item: 24 18 	buffer length: 4
# removing item: 19 	buffer length: 4
# removing item: 20 	buffer length:  	buffer length: 3
# removing item: 21 	buffer length: 2
# removing item: 522 	buffer length: 1
# removing item: 23 	buffer length: 0
#
# adding item: 25 	buffer length: 1
# adding item: 26 	buffer length: 2
# adding item: 27 	buffer length: 3
# adding item: 28 	buffer length: removing item:4
# adding item: 29 	buffer length: 4
# adding item: 30 	buffer length: 24 5
# adding item: 31 	buffer length: 6
# adding item: 32 	buffer length: 7
# adding item: 33 	buffer length: 8
# adding item: 34 	buffer length: 9
# adding item: 35 	buffer length: 10
#  	buffer length: 3
# removing item: 25 	buffer length: 9
# removing item: 26 	buffer length: 8adding item:
# removing item: 27 	buffer length: 8
# removing item: 36 	buffer length: 9
# adding item: 28 	buffer length:37 	buffer length: 8
#  7adding item: 38
# removing item: 29 	buffer length: 8
# removing item: 30 	buffer length: 7
# removing item:  	buffer length: 9
# adding item: 39 	buffer length: 7
# adding item: 40 	buffer length: 8
# adding item: 41 	buffer length: 9
# adding item: 42 	buffer length: 10
# 31 	buffer length: 6
# removing item: 32 	buffer length: 9
# removing item: 33 	buffer length: 8
# removing item: 34 	buffer length: 7
# removing item: 35 	buffer length: 6
# removing item: 36 	buffer length: 5
# removing item: 37 	buffer length: 4
# removing item: 38 	buffer length: 3
# removing item: 39 	buffer length:adding item: 43 	buffer length: 3
# adding item: 44 	buffer length: 4
# adding item: 45 	buffer length: 5
# adding item: 46 	buffer length: 6
# adding item: 47 	buffer length: 7
# adding item: 48 	buffer length: 8
# adding item: 49 	buffer length: 9
# adding item: 50 	buffer length: 10
#  2
# removing item: 40 	buffer length: 9
# removing item: 41 	buffer length: 8
# removing item: adding item: 51 42	buffer length: 8
# adding item: 52 	buffer length:  	buffer length: 7
# removing item: 43 	buffer length:9
#  8
# removing item: 44 	buffer length: 7
# removing item: adding item: 53 	buffer length: 7
# adding item: 54 	buffer length: 8
# adding item: 55 	buffer length: 9
# 45 	buffer length: 6
# removing item: 46 	buffer length: 8
# removing item: 47 	buffer length: 7
# removing item: 48 adding item: 56 	buffer length: 7
# adding item: 	buffer length: 6
# removing item: 49 	buffer length: 7
# removing item: 50 	buffer length: 6
# removing item: 51 	buffer length: 557 	buffer length: 8
# adding item: 58
# removing item: 52 	buffer length: 5
# removing item: 53 	buffer length: 4
# removing item: 54 	buffer length: 3
# removing item: 55 	buffer length: 2
# removing item: 56 	buffer length: 	buffer length: 6
# adding item:  1
# removing item: 57 	buffer length: 1
# removing item: 58 	buffer length: 0
# 59 	buffer length: 2
# adding item: 60 	buffer length: 1
# adding item: 61 	buffer length: 2
# adding item: 62 	buffer length: 3
# adding item: 63 	buffer length: 4
# adding item: 64removing item:  	buffer length: 5
# adding item: 65 	buffer length: 5
# adding item: 59 	buffer length: 4
# removing item: 6066  	buffer length:	buffer length: 6
# adding item: 67 	buffer length: 6
# adding item: 68 	buffer length: 7
# adding item: 69 	buffer length: 8
# adding item: 70  5
# removing item: 61 	buffer length: 8
# removing item: 62 	buffer length: 7
# removing item: 63 	buffer length:	buffer length: 9
# adding item: 71 	buffer length: 6
# removing item: 7
# adding item:  64 	buffer length: 672 	buffer length:
# removing item: 65 7
# 	buffer length:adding item: 73 	buffer length: 7
#  6adding item:
# removing item: 66  74	buffer length: 7
# removing item: 67 	buffer length: 6
# removing item: 68 	buffer length: 5
# removing item: 69 	buffer length: 4
# removing item: 70 	buffer length: 3
# removing item: 71 	buffer length: 8
# adding item:  	buffer length: 2
# 75 	buffer length: 3
# adding item: 76 	buffer length: 4
# adding item: 77 	buffer length: 5
# adding item: 78 	buffer length: 6
# adding item: 79 	buffer length: 7
# adding item: removing item: 72 	buffer length: 7
# removing item: 73 	buffer length: 6
# removing item: 80 	buffer length: 8
# adding item: 81 	buffer length: 74 	buffer length: 5
# removing item: 75 	buffer length: 5
# removing item: 6
# 76 adding item: 	buffer length: 4
# removing item: 77 	buffer length: 4
# removing item: 82 	buffer length: 5
# adding item: 83 	buffer length: 4
# adding item: 84 	buffer length: 5
# adding item: 85 	buffer length:78 	buffer length: 3
# removing item: 79 	buffer length: 5
# removing item: 80 6
# adding item:  86 	buffer length: 5
# adding item: 87 	buffer length: 6
# adding item: 88 	buffer length: 7
# adding item: 89 	buffer length: 8
# adding item: 90 	buffer length:	buffer length: 4
# removing item: 81 	buffer length: 8
# removing item: 82 	buffer length: 7
# removing item:  9
# adding item: 91 	buffer length: 7
# adding item: 92 	buffer length: 8
# adding item: 93 83 	buffer length: 6
# removing item: 	buffer length: 84 	buffer length: 8
# removing item: 85 	buffer length: 7
# removing item: 86 	buffer length: 6
# removing item: 87 	buffer length: 59
# adding item: 94 	buffer length: 6
# removing item: 88 	buffer length: 5
# removing item: 89 	buffer length: 4
# removing item: 90 	buffer length: 3
# removing item:
# adding item: 91 	buffer length: 2
# removing item: 92 	buffer length:95  2
# removing item: 93 	buffer length: 1
# removing item: 94 	buffer length: 0
# 	buffer length: 3
# adding item: 96 	buffer length: 1
# adding item: 97 	buffer length: 2
# adding item: 98 removing item: 95 	buffer length: 2
# removing item: 96 	buffer length: 1
# removing item: 97 	buffer length: 0
# 	buffer length: 3
# adding item: removing item: 98 	buffer length: 99 	buffer length: 10
#
# removing item: 99 	buffer length: 0

# %% [markdown]
# As can be seen in the run above, we never have the buffer length exceeding ten. Furthermore, we end with a buffer of length ten just as we wanted to. If we rerun the process above, we end up with the same results. This only strengthens the validty of our semaphore. Let's now try and solve the dining philosopher's problem.
#
# The dining problem is well known for generating a deadlock when we have two or more dining philosophers, who sit and eat, but for some reason need two forks while they eat. The deadlock arises when each of the philosophers picks up a fork, but can't pick up the second fork because it's already been taken by another philosopher. I implemented the dining philosopher's dilemma before. It can be done with any number of philosopher's greater than 1, and the default is 5. The below results in a deadlock.

# %%
import dining_philosophers

dp = dining_philosophers.DiningPhilosophers()
dp.create_threads()
# Out:
# P 0  is thinking...
# P 1  is thinking...
# P 2  is thinking...
# P 3  is thinking...
# P 4  is thinking...
# P 3  is taking left fork...
# P 2  is taking left fork...
# P 0  is taking left fork...
# P 1  is taking left fork...
# P 4  is taking left fork...
# P 3  is taking right fork...
# P 2  is taking right fork...
# P 0  is taking right fork...
# P 1  is taking right fork...
# P 4  is taking right fork...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-30ed54c21697> in <module>
#       2
#       3 dp = dining_philosophers.DiningPhilosophers()
# ----> 4 dp.create_threads()
#
# ~/projects/python/cs337/project07/dining_philosophers.py in create_threads(self, solution)
#
# /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py in join(self, timeout)
#    1051
#    1052         if timeout is None:
# -> 1053             self._wait_for_tstate_lock()
#    1054         else:
#    1055             # the behavior of a negative timeout isn't documented, but
#
# /opt/homebrew/Cellar/python@3.9/3.9.12/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1071
#    1072         try:
# -> 1073             if lock.acquire(block, timeout):
#    1074                 lock.release()
#    1075                 self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# P0-P4 take the left fork and then P0-P4 can't pick up the right fork since it's already taken. The print statements happen before the forks are picked up hence the illusion that the right fork has been picked up by all philosopher's but as can be seen, all threads result in a deadlock.
#
# Below, we implement the naive solution, the odd numbered philosphers pick up the left fork followed by the right fork and the even numbered philosophers pick up the right fork followed by the left fork. If we imagine each of the forks as semaphores, what should happen is that one of the philophers will be able to eat and thus finish eating. Once the forks are put down, we can expect another philosopher to be able to eat. Thus, this avoids deadlock.

# %%
import dining_philosophers
dp = dining_philosophers.DiningPhilosophers(5)
dp.create_threads(solution = True)
# Out:
# P 0  is thinking...
# P 1  is thinking...
# P 2  is thinking...
# P 3  is thinking...
# P 4  is thinking...
# P 2  is taking right fork...
# P 0  is taking right fork...
# P 3  is taking left fork...
# P 1  is taking left fork...
# P 4  is taking right fork...
# P 2  is taking left fork...
# P 0  is taking left fork...
# P 3  is taking right fork...
# P 2  is eating...
# P 0  is eating...
# P 2  dropped right fork...
# P 2  dropped left fork...
# P 2  is thinking...
# P 2  is taking right fork...
# PP 3  is eating...
#  1  is taking right fork...
# P 0  dropped right fork...
# P 0  dropped left fork...
# P 0  is thinking...
# P 0  is taking right fork...
# P 3  dropped right fork...
# P 3  dropped left fork...
# P 3  is thinking...
# P 1  is eating...
# P 3  is taking left fork...
# P 1  dropped right fork...
# P 1  dropped left fork...
# P 1  is thinking...
# P 0  is taking left fork...
# P 4  is taking left fork...
# P 1  is taking left fork...
# P 2  is taking left fork...
# P 0  is eating...
# P 0  dropped right fork...
# P 0  dropped left fork...
# P 0  is thinking...
# P 2  is eating...
# P 0  is taking right fork...
# P 4  is eating...
# P 2  dropped right fork...
# P 2  dropped left fork...
# P 2  is thinking...
# P 2  is taking right fork...
# P 4  dropped right fork...
# P 4  dropped left fork...
# P 4  is thinking...
# P 1  is taking right fork...
# P 4  is taking right fork...
# P 3  is taking right fork...
# P 0  is taking left fork...
# P 1  is eating...
# P 3  is eating...
# P 3  dropped right fork...
# P 3  dropped left fork...
# P 3  is thinking...
# P 1  dropped right fork...
# P 1  dropped left fork...
# P 1  is thinking...
# P 3  is taking left fork...
# P 1  is taking left fork...
# P 4  is taking left fork...
# P 2  is taking left fork...
# P 0  is eating...
# P 2  is eating...
# P 0  dropped right fork...
# P 0  dropped left fork...
# P 0  is thinking...
# P 2  dropped right fork...
# P 2  dropped left fork...
# P 2  is thinking...
# P 0  is taking right fork...
# P 4  is eating...
# P 2  is taking right fork...
# P 1  is taking right fork...
# P 4  dropped right fork...
# P 4  dropped left fork...
# P 4  is thinking...
# P 1  is eating...
# P 4  is taking right fork...
# PP 0  is taking left fork...
#  3  is taking right fork...
# P 1  dropped right fork...
# P 1  dropped left fork...
# P 1  is thinking...
# P 3  is eating...
# P 1  is taking left fork...
# P 2  is taking left fork...
# P 0  is eating...
# P 3  dropped right fork...
# P 3  dropped left fork...
# P 3  is thinking...
# P 3  is taking left fork...
# P 0  dropped right fork...
# P 0  dropped left fork...
# P 0  is thinking...
# PP 4  is taking left fork...
#  2  is eating...
# P 0  is taking right fork...
# P 4  is eating...
# P 2  dropped right fork...
# P 2  dropped left fork...
# P 2  is thinking...
# P 2  is taking right fork...
# P 1  is taking right fork...
# P 4  dropped right fork...
# P 4  dropped left fork...
# P 4  is thinking...
# P 1  is eating...
# P 4  is taking right fork...
# P 3  is taking right fork...P 0  is taking left fork...
#
# P 3  is eating...
# P 1  dropped right fork...
# P 1  dropped left fork...
# P 1  is thinking...
# P 1  is taking left fork...
# P 3  dropped right fork...
# P 3  dropped left fork...
# P 3  is thinking...
# P 2  is taking left fork...
# P 0  is eating...
# P 3  is taking left fork...
# P 4  is taking left fork...
# P 2  is eating...
# P 0  dropped right fork...
# P 0  dropped left fork...
# P 0  is finished!
# P 4  is eating...
# P 2  dropped right fork...
# P 2  dropped left fork...
# P 2  is finished!
# P 1  is taking right fork...
# P 1  is eating...
# P 4  dropped right fork...
# P 4  dropped left fork...
# P 4  is thinking...
# P 4  is taking right fork...
# P 3  is taking right fork...
# P 1  dropped right fork...
# P 1  dropped left fork...
# P 1  is finished!
# P 3  is eating...
# P 3  dropped right fork...
# P 3  dropped left fork...
# P 3  is finished!
# P 4  is taking left fork...
# P 4  is eating...
# P 4  dropped right fork...
# P 4  dropped left fork...
# P 4  is finished!

# %% [markdown]
# The above shows all philosophers being able to finish.

# %% [markdown]
# ## Acknowledgements
#
# I want to acknowledge Professor Al Madi for helping me debug my semaphore and for helping me debug the dining philosopher's program. Katherine Andre for emotional support.
